# %%
from google.colab import files
 
uploaded = files.upload()
 
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
    name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-8678aa86-872a-4681-82cd-3565d6823b8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8678aa86-872a-4681-82cd-3565d6823b8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance (2).csv
# User uploaded file "StudentsPerformance.csv" with length 72036 bytes

# %%
# !ls
# Out:
#  sample_data		       'StudentsPerformance (2).csv'
# 'StudentsPerformance (1).csv'   StudentsPerformance.csv

# %%
import pandas as df

# %%
students =  pd.read_csv(r"StudentsPerformance (1).csv")
students.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
students.plot.scatter("math score" , "reading score")

# %%
stu =students[students["reading score"]>88]

# %%
stu.head()
# Out:
#     gender race/ethnicity  ... reading score writing score
# 1   female        group C  ...            90            88
# 2   female        group B  ...            95            93
# 6   female        group B  ...            95            92
# 16    male        group C  ...            89            86
# 38  female        group D  ...            90            88
#
# [5 rows x 8 columns]

# %%
std = df

# %%
import seaborn as sns
sns.countplot( [ 'gender' ])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
